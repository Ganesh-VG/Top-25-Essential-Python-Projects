# %% [markdown]
# <a href="https://colab.research.google.com/github/Ganesh-VG/Ganesh_Projects/blob/main/1DataScience_Web_Scraping_and_data_wrangling_on_top_movies_and_TV_show_data_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Web Scraping & Data Handling Challenge**

# %% [markdown]
# ### **Website:**
# JustWatch -  https://www.justwatch.com/in/movies?release_year_from=2000
#
#
# ### **Description:**
#
# JustWatch is a popular platform that allows users to search for movies and TV shows across multiple streaming services like Netflix, Amazon Prime, Hulu, etc. For this assignment, you will be required to scrape movie and TV show data from JustWatch using Selenium, Python, and BeautifulSoup. Extract data from HTML, not by directly calling their APIs. Then, perform data filtering and analysis using Pandas, and finally, save the results to a CSV file.
#
# ### **Tasks:**
#
# **1. Web Scraping:**
#
# Use BeautifulSoup to scrape the following data from JustWatch:
#
#    **a. Movie Information:**
#
#       - Movie title
#       - Release year
#       - Genre
#       - IMDb rating
#       - Streaming services available (Netflix, Amazon Prime, Hulu, etc.)
#       - URL to the movie page on JustWatch
#
#    **b. TV Show Information:**
#
#       - TV show title
#       - Release year
#       - Genre
#       - IMDb rating
#       - Streaming services available (Netflix, Amazon Prime, Hulu, etc.)
#       - URL to the TV show page on JustWatch
#
#   **c. Scope:**
#
# ```
#  ` - Scrape data for at least 50 movies and 50 TV shows.
#    - You can choose the entry point (e.g., starting with popular movies,
#      or a specific genre, etc.) to ensure a diverse dataset.`
#
# ```
#
#
# **2. Data Filtering & Analysis:**
#
#    After scraping the data, use Pandas to perform the following tasks:
#
#    **a. Filter movies and TV shows based on specific criteria:**
#
#    ```
#       - Only include movies and TV shows released in the last 2 years (from the current date).
#       - Only include movies and TV shows with an IMDb rating of 7 or higher.
# ```
#
#    **b. Data Analysis:**
#
#    ```
#       - Calculate the average IMDb rating for the scraped movies and TV shows.
#       - Identify the top 5 genres that have the highest number of available movies and TV shows.
#       - Determine the streaming service with the most significant number of offerings.
#
#    ```
#
# **3. Data Export:**
#
# ```
#    - Dump the filtered and analysed data into a CSV file for further processing and reporting.
#
#    - Keep the CSV file in your Drive Folder and Share the Drive link on the colab while keeping view access with anyone.
# ```
#
# **Submission:**
# ```
# - Submit a link to your Colab made for the project.
#
# - The Colab should contain your Python script (.py format only) with clear
#   comments explaining the scraping, filtering, and analysis process.
#
# - Your Code shouldn't have any errors and should be executable at a one go.
#
# - Before Conclusion, Keep your Dataset Drive Link in the Notebook.
# ```
#
#
#
# **Note:**
#
# 1. Properly handle errors and exceptions during web scraping to ensure a robust script.
#
# 2. Make sure your code is well-structured, easy to understand, and follows Python best practices.
#
# 3. The assignment will be evaluated based on the correctness of the scraped data, accuracy of data filtering and analysis, and the overall quality of the Python code.

# %% [markdown]
# # **Start The Project**

# %% [markdown]
# ## **Task 1:- Web Scrapping**

# %%
#Installing all necessary labraries
# !pip install bs4
# !pip install requests
# !pip install wordcloud
# Out:
# Requirement already satisfied: bs4 in /usr/local/lib/python3.10/dist-packages (0.0.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from bs4) (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->bs4) (2.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.2.2)
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.10/dist-packages (1.9.3)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.10/dist-packages (from wordcloud) (1.25.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from wordcloud) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (24.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %%
#import all necessary labraries
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd
import numpy as np
import time
from datetime import datetime, timedelta

# %% [markdown]
# ## **Scrapping Movies Data**

# %%
# Specifying the URL from which movies related data will be fetched
url='https://www.justwatch.com/in/movies?release_year_from=2000'

# Sending an HTTP GET request to the URL
page=requests.get(url)

# Parsing the HTML content using BeautifulSoup with the 'html.parser'
movie_soup=BeautifulSoup(page.text,'html.parser')

# Printing the prettified HTML content
# print(soup.prettify())

# %% [markdown]
# ## **Fetching Movie URL's**

# %%
# fetching href data of each page and appending it with required prefix.
movie_url = ["https://www.justwatch.com" + url["href"] for url in movie_soup.find_all("a", class_ = "title-list-grid__item--link")]

# %% [markdown]
# ## **Getting movies data**

# %%
movie_data = []

for url in movie_url[:50]:
    while True:
        page = requests.get(url)

        if page.status_code == 200:
            # If the request is successful, append the response to Tv_show_data and break the loop
            movie_data.append(page)
            break
        elif page.status_code == 429:
            # If the status code is 429, wait for a while and then retry
            print("Too many requests. Waiting before retrying...")
            time.sleep(10)  # You can adjust the sleep time as needed
        else:
            # Handle other status codes if needed
            print("Unexpected status code:", page.status_code)
            break
# Out:
# Too many requests. Waiting before retrying...
# Too many requests. Waiting before retrying...
# Too many requests. Waiting before retrying...
# Too many requests. Waiting before retrying...
# Too many requests. Waiting before retrying...
# Too many requests. Waiting before retrying...
# Too many requests. Waiting before retrying...
# Too many requests. Waiting before retrying...
# Too many requests. Waiting before retrying...

# %% [markdown]
# ## **Scrapping Movie Title**

# %%
movie_dataset = {}
movie_title = []

for page in movie_data:
  # Parsing the HTML content using BeautifulSoup from the 'movie_data'
  soup_movies = BeautifulSoup(page.text,'html.parser')

  # append title from extracted data into a list
  movie_title.append(soup_movies.find("h1").text.strip().split(" (")[0].strip())

# adding list of all movies into dictionary with appropriate key
movie_dataset["Movie Title"] = movie_title

# %% [markdown]
# ## **Scrapping release Year**

# %%
movie_release_year = []

for page in movie_data:
  # Parsing the HTML content using BeautifulSoup from the 'movie_data'
  soup_movies = BeautifulSoup(page.text,'html.parser')

  year_data = soup_movies.find("h1").text.strip().split(" (")[1].strip(")")

  # append release year from extracted data into a list
  movie_release_year.append(datetime.strptime(year_data, '%Y').year)

# adding list of all movies into dictionary with appropriate key
movie_dataset["Movie Release Year"] = movie_release_year

# %% [markdown]
# ## **Scraping Movie Details**

# %%
'''
This step avoids repeatative scraping of html file for data
which will make the further code more efficient and
less time consuming.It also avoids mismatch of data.
'''
movie_details = []

for page in movie_data:
  each_movie = {} # initialising dictionary
  soup_movies = BeautifulSoup(page.text,'html.parser')

  # scraping subheadings of details into a list
  detail_head = [data.text[:19].strip() for data in soup_movies.find("div", class_ = "title-info title-info").find_all("h3", class_ = "detail-infos__subheading")]

  # scraping details into the list
  details_tail = [data.text.strip() for data in soup_movies.find("div", class_ = "title-info title-info").find_all("div", class_ = "detail-infos__value")]

  # assigning subheading as dictionary keys and respective details as dictionary values
  for i in range(len(detail_head)):
    each_movie[detail_head[i]] = details_tail[i]

  # appending dictionary of each movie details into a list for further use
  movie_details.append(each_movie)

# %% [markdown]
# ## **Scrapping Genres**

# %%
# Fetching data directly from list created by scraping and storing into a Dictionary
movie_genres = [key.get('Genres') for key in movie_details]

movie_dataset["Movie Genres"] = movie_genres

# %% [markdown]
# ## **Scrapping IMBD Rating**

# %%
# Fetching rating data and storing it as float datatype.
movie_imdb_rating = [None if len(key.get('Rating')) == 0 else float(key.get('Rating').strip().split(" ")[0]) for key in movie_details]

movie_dataset["Movie IMDB Rating"] = movie_imdb_rating

# %% [markdown]
# ## **Scrapping Runtime/Duration**

# %%
def convert_duration_to_timedelta(time_str):
  '''
  function that convert raw time data into a standard format
  input : 3h 0min
  output : 03:00:00
  '''
  # Split the string into hours and minutes parts
  time_parts = time_str.split()

  # Initialize hours and minutes
  hours = 0
  minutes = 0

  # Loop through the time parts to extract hours and minutes
  for part in time_parts:
      if 'h' in part:
          hours = int(part.strip('h'))
      elif 'min' in part:
          minutes = int(part.strip('min'))

  # Create a datetime object with the given hours and minutes
  time_obj = datetime.strptime(f'{hours}:{minutes}', '%H:%M').time()

  return(time_obj)

# %%
'''
extract runtime of each movie from data pass it onto
'convert_duration_to_timedelta()' function and append the output into a list.
'''
movie_runtime = [str(convert_duration_to_timedelta(key.get('Runtime')))  for key in movie_details]

movie_dataset["Movie Runtime"] = movie_runtime

# %% [markdown]
# ## **Scrapping Age Rating**

# %%
# Extract Age rating of each movie if available and append it into a list.
movie_age_rating = [key.get('Age rating') for key in movie_details]

movie_dataset["Movie Age Rating"] = movie_age_rating

# %% [markdown]
# ## **Fetching Production Countries Details**

# %%
# extract details about where the movie was produced and append it into list
movie_production_countries = [key.get('Production country') for key in movie_details]

movie_dataset["Movie Production Countries"] = movie_production_countries

# %% [markdown]
# ## **Fetching Streaming Service Details**

# %%
# extract Streaming Service details and append it into list
movie_stream_services = []

for page in movie_data:
  soup_movies = BeautifulSoup(page.text,'html.parser')

  # if the attribute the code is looking for is not present in the website it will append none
  try:
    # if multiple streaming services are available for single movie it will append each into a list
    movie_stream_services.append([ data["alt"] for data in soup_movies.find("div", class_ = "buybox-row stream").find_all("img", class_ = "offer__icon")])
  except AttributeError:
    movie_stream_services.append(None)

# after getting data for each movie it append data into main list
movie_stream_services_join = [None if data == None else ", ".join(data) if len(data) > 1 else data[0] for data in movie_stream_services]

movie_dataset["Movie Stream Services"] = movie_stream_services_join

# %% [markdown]
# ## **Now Creating Movies DataFrame**

# %%
# convert dictionary dataset into a dataframe
movie_df = pd.DataFrame(movie_dataset)
movie_df
# Out:
#                                  Movie Title  Movie Release Year  \
# 0                                Oppenheimer                2024
# 1                                       Dune                2021
# 2                                   Hanu-Man                2024
# 3                                     Animal                2023
# 4                                     Salaar                2023
# 5                                Poor Things                2023
# 6                                  12th Fail                2023
# 7                           The Kerala Story                2023
# 8                                      Dunki                2023
# 9                             Anyone But You                2023
# 10                               Sam Bahadur                2023
# 11                                     Eagle                2024
# 12                               Article 370                2024
# 13                           Merry Christmas                2024
# 14          Teri Baaton Mein Aisa Uljha Jiya                2024
# 15                            Captain Miller                2024
# 16                                Bramayugam                2024
# 17                             Guntur Kaaram                2024
# 18                                   Fighter                2024
# 19                                   Ayalaan                2024
# 20                     Anweshippin Kandethum                2024
# 21                         Anatomy of a Fall                2023
# 22                            Manjummel Boys                2024
# 23              Aquaman and the Lost Kingdom                2023
# 24                            Dune: Part Two                2024
# 25                                    Code 8                2019
# 26                                     Jawan                2023
# 27                          American Fiction                2023
# 28                           Laapataa Ladies                2024
# 29                                    Damsel                2024
# 30                                  365 Days                2020
# 31                          Singapore Saloon                2024
# 32             Crakk: Jeetega... Toh Jiyegaa                2024
# 33                          Sound of Freedom                2023
# 34                      The Zone of Interest                2023
# 35                                   Premalu                2024
# 36  Harry Potter and the Philosopher's Stone                2001
# 37                                    Barbie                2023
# 38                             The Holdovers                2023
# 39                             The Beekeeper                2024
# 40                Killers of the Flower Moon                2023
# 41                      Malaikottai Vaaliban                2024
# 42                     Vadakkupatti Ramasamy                2024
# 43                                    Junior                2023
# 44                            Code 8 Part II                2024
# 45                                    Aattam                2024
# 46                                  Upgraded                2024
# 47                                Past Lives                2023
# 48                                BlackBerry                2023
# 49                        Godzilla Minus One                2023
#
#                                          Movie Genres  Movie IMDB Rating  \
# 0                                      Drama, History                8.3
# 1          Science-Fiction, Action & Adventure, Drama                8.0
# 2   Action & Adventure, Comedy, Science-Fiction, F...                8.4
# 3   Action & Adventure, Crime, Drama, Mystery & Th...                6.3
# 4   Action & Adventure, Crime, Drama, Mystery & Th...                6.5
# 5             Science-Fiction, Romance, Comedy, Drama                8.1
# 6                                               Drama                9.0
# 7                                               Drama                7.0
# 8                                       Comedy, Drama                6.7
# 9                                     Comedy, Romance                6.2
# 10                              Drama, War & Military                7.8
# 11             Action & Adventure, Mystery & Thriller                6.7
# 12      Action & Adventure, Drama, Mystery & Thriller                8.5
# 13                          Drama, Mystery & Thriller                7.2
# 14            Science-Fiction, Comedy, Drama, Romance                7.0
# 15  Action & Adventure, Drama, Mystery & Thriller,...                6.6
# 16                         Horror, Mystery & Thriller                8.3
# 17                          Action & Adventure, Drama                5.4
# 18  Action & Adventure, Mystery & Thriller, War & ...                6.9
# 19                Action & Adventure, Science-Fiction                6.0
# 20                   Crime, Drama, Mystery & Thriller                7.6
# 21                   Mystery & Thriller, Crime, Drama                7.8
# 22                          Mystery & Thriller, Drama                8.7
# 23       Action & Adventure, Fantasy, Science-Fiction                5.6
# 24         Action & Adventure, Science-Fiction, Drama                8.9
# 25  Action & Adventure, Crime, Science-Fiction, Dr...                6.1
# 26      Action & Adventure, Mystery & Thriller, Drama                7.0
# 27                                      Comedy, Drama                7.6
# 28                                      Comedy, Drama                8.4
# 29                        Action & Adventure, Fantasy                6.2
# 30                     Romance, Drama, Made in Europe                3.3
# 31                       Kids & Family, Comedy, Drama                6.2
# 32      Action & Adventure, Mystery & Thriller, Sport                6.4
# 33  Action & Adventure, Drama, Crime, History, Mys...                7.7
# 34                     Drama, War & Military, History                7.5
# 35                                    Comedy, Romance                8.3
# 36         Action & Adventure, Fantasy, Kids & Family                7.6
# 37                                    Comedy, Fantasy                6.9
# 38                                      Comedy, Drama                8.0
# 39      Action & Adventure, Mystery & Thriller, Drama                6.4
# 40            Crime, History, Drama, Romance, Western                7.6
# 41  Fantasy, Action & Adventure, Drama, Mystery & ...                6.4
# 42            Comedy, Drama, Fantasy, Science-Fiction                6.4
# 43                                 Action & Adventure                7.7
# 44  Action & Adventure, Crime, Science-Fiction, My...                5.7
# 45                                              Drama                8.4
# 46                                    Romance, Comedy                6.1
# 47                                     Romance, Drama                7.9
# 48                             Comedy, Drama, History                7.4
# 49  Action & Adventure, Science-Fiction, Drama, Ho...                8.3
#
#    Movie Runtime Movie Age Rating              Movie Production Countries  \
# 0       03:01:00               UA           United Kingdom, United States
# 1       02:35:00               UA                           United States
# 2       02:39:00               UA                                   India
# 3       03:21:00                A                                   India
# 4       02:55:00                A                                   India
# 5       02:22:00                A  United Kingdom, United States, Ireland
# 6       02:27:00             None                                   India
# 7       02:18:00                A                                   India
# 8       02:40:00             None                                   India
# 9       01:43:00             None                Australia, United States
# 10      02:30:00               UA                                   India
# 11      02:39:00               UA                                   India
# 12      02:38:00               UA                                   India
# 13      02:23:00             None                                   India
# 14      02:21:00             None                                   India
# 15      02:37:00               UA                                   India
# 16      02:19:00               UA                                   India
# 17      02:39:00               UA                                   India
# 18      02:47:00               UA                                   India
# 19      02:35:00             None                                   India
# 20      02:22:00             None                                   India
# 21      02:32:00             None                                  France
# 22      02:15:00               UA                                   India
# 23      02:04:00             None                           United States
# 24      02:47:00             None                           United States
# 25      01:39:00                A   Canada, United Kingdom, United States
# 26      02:49:00               UA                                   India
# 27      01:57:00             None                           United States
# 28      02:02:00             None                                   India
# 29      01:50:00             None                           United States
# 30      01:54:00             None                                  Poland
# 31      02:17:00               UA                                   India
# 32      02:34:00             None                                   India
# 33      02:11:00             None                           United States
# 34      01:45:00               UA   United States, Poland, United Kingdom
# 35      02:36:00                U                                   India
# 36      02:32:00                U           United Kingdom, United States
# 37      01:54:00               UA           United States, United Kingdom
# 38      02:13:00             None                           United States
# 39      01:45:00             None           United Kingdom, United States
# 40      03:26:00                A                           United States
# 41      02:34:00               UA                                   India
# 42      02:24:00                U                                   India
# 43      02:02:00             None                                   India
# 44      01:41:00             None                   Canada, United States
# 45      02:19:00               UA                                   India
# 46      01:45:00             None           United Kingdom, United States
# 47      01:46:00               UA              South Korea, United States
# 48      02:00:00             None                                  Canada
# 49      02:05:00             None                                   Japan
#
#                                 Movie Stream Services
# 0                                          Jio Cinema
# 1                                             Netflix
# 2                                                None
# 3                                             Netflix
# 4                                             Netflix
# 5                                                None
# 6                                             Hotstar
# 7                                                Zee5
# 8                                             Netflix
# 9                                                None
# 10                                               Zee5
# 11                                 Amazon Prime Video
# 12                                               None
# 13                                            Netflix
# 14                                               None
# 15                        Amazon Prime Video, Sun Nxt
# 16                                           Sony Liv
# 17                                            Netflix
# 18                                               None
# 19                                            Sun Nxt
# 20                                            Netflix
# 21                                               None
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                 Amazon Prime Video
# 26                                            Netflix
# 27                                 Amazon Prime Video
# 28                                               None
# 29                                            Netflix
# 30                                            Netflix
# 31                                 Amazon Prime Video
# 32                                               None
# 33                                 Amazon Prime Video
# 34                                               None
# 35                                               None
# 36                                         Jio Cinema
# 37                                         Jio Cinema
# 38                                               None
# 39                                               None
# 40                                      Apple TV Plus
# 41                                               None
# 42                            Amazon Prime Video, aha
# 43                                 Amazon Prime Video
# 44                                            Netflix
# 45                                 Amazon Prime Video
# 46                                 Amazon Prime Video
# 47  Lionsgate Play, Lionsgate Play Apple TV Channe...
# 48                                 Amazon Prime Video
# 49                                               None

# %% [markdown]
# ## **Scraping TV  Show Data**

# %%
# Specifying the URL from which tv show related data will be fetched
tv_url='https://www.justwatch.com/in/tv-shows?release_year_from=2000'

# Sending an HTTP GET request to the URL
page=requests.get(tv_url)

# Parsing the HTML content using BeautifulSoup with the 'html.parser'
Tv_show_soup=BeautifulSoup(page.text,'html.parser')

# Printing the prettified HTML content
# print(soup1.prettify())

# %% [markdown]
# ## **Fetching Tv shows Url details**

# %%
# fetching href data of each page and appending it with required prefix.
Tv_show_url = ["https://www.justwatch.com" + url["href"] for url in Tv_show_soup.find_all("a", class_ = "title-list-grid__item--link")]

# %% [markdown]
# ## **Getting TV show data**

# %%
Tv_show_data = []

for url in Tv_show_url[:50]:
    while True:
        page = requests.get(url)

        if page.status_code == 200:
            # If the request is successful, append the response to Tv_show_data and break the loop
            Tv_show_data.append(page)
            break
        elif page.status_code == 429:
            # If the status code is 429, wait for a while and then retry
            print("Too many requests. Waiting before retrying...")
            time.sleep(10)  # You can adjust the sleep time as needed
        else:
            # Handle other status codes if needed
            print("Unexpected status code:", page.status_code)
            break
# Out:
# Too many requests. Waiting before retrying...
# Too many requests. Waiting before retrying...
# Too many requests. Waiting before retrying...
# Too many requests. Waiting before retrying...
# Too many requests. Waiting before retrying...
# Too many requests. Waiting before retrying...
# Too many requests. Waiting before retrying...
# Too many requests. Waiting before retrying...
# Too many requests. Waiting before retrying...
# Too many requests. Waiting before retrying...
# Too many requests. Waiting before retrying...
# Too many requests. Waiting before retrying...
# Too many requests. Waiting before retrying...
# Too many requests. Waiting before retrying...
# Too many requests. Waiting before retrying...
# Too many requests. Waiting before retrying...

# %% [markdown]
# ## **Fetching Tv Show Title details**

# %%
# Write Your Code here
Tv_show_dataset = {}
Tv_show_title = []

for page in Tv_show_data:
  # Parsing the HTML content using BeautifulSoup from the 'movie_data'
  soup_Tv_show = BeautifulSoup(page.text,'html.parser')

  # append title from extracted data into a list
  Tv_show_title.append(soup_Tv_show.find("h1").text.strip().split(" (")[0].strip())

# adding list of all movies into dictionary with appropriate key
Tv_show_dataset["TV Show Title"] = Tv_show_title

# %% [markdown]
# ## **Fetching Release Year**

# %%
Tv_show_release_year = []

for page in Tv_show_data:
  # Parsing the HTML content using BeautifulSoup from the 'movie_data'
  soup_Tv_show = BeautifulSoup(page.text,'html.parser')

  year_data = soup_Tv_show.find("h1").text.strip().split(" (")[1].strip(")")

  # append release year from extracted data into a list
  Tv_show_release_year.append(datetime.strptime(year_data, '%Y').year)

# adding list of all movies into dictionary with appropriate key
Tv_show_dataset["TV Show Year"] = Tv_show_release_year

# %% [markdown]
# ## **Scraping TV Show Details**

# %%
'''
This step avoids repeatative scraping of html file for data
which will make the further code more efficient and
less time consuming.It also avoids mismatch of data.
'''
Tv_show_details = []
for page in Tv_show_data:
  each_Tv_show = {} # initialising dictionary
  soup_Tv_show = BeautifulSoup(page.text,'html.parser')

  # scraping subheadings of details into a list
  detail_head = [data.text[:19].strip() for data in soup_Tv_show.find("div", class_ = "title-info title-info").find_all("h3", class_ = "detail-infos__subheading")]

  # scraping details into the list
  details_tail = [data.text.strip() for data in soup_Tv_show.find("div", class_ = "title-info title-info").find_all("div", class_ = "detail-infos__value")]

  # assigning subheading as dictionary keys and respective details as dictionary values
  for i in range(len(detail_head)):
    each_Tv_show[detail_head[i]] = details_tail[i]

  # appending dictionary of each movie details into a list for further use
  Tv_show_details.append(each_Tv_show)

# %% [markdown]
# ## **Fetching TV Show Genre Details**

# %%
# Fetching data directly from list created by scraping and storing into a Dictionary.
Tv_show_genres = [key.get('Genres') for key in Tv_show_details]

Tv_show_dataset["TV Show Genres"] = Tv_show_genres

# %% [markdown]
# ## **Fetching IMDB Rating Details**

# %%
# Fetching rating data and storing it as float datatype.
Tv_show_imdb_rating = [None if len(key.get('Rating')) == 0 else float(key.get('Rating').strip().split(" ")[0]) for key in Tv_show_details]

Tv_show_dataset["TV Show IMDB Rating"] = Tv_show_imdb_rating

# %% [markdown]
# ## **Fetching Age Rating Details**

# %%
# Extract Age rating of each movie if available and append it into a list.
Tv_show_age_rating = [key.get('Age rating') for key in Tv_show_details]

Tv_show_dataset["TV Show Age Rating"] = Tv_show_age_rating

# %% [markdown]
# ## **Fetching Production Country details**

# %%
# extract details about where the TV Show was produced and append it into list
Tv_show_production_countries = [key.get('Production country') for key in Tv_show_details]

Tv_show_dataset["TV Show Production Countries"] = Tv_show_production_countries

# %% [markdown]
# ## **Fetching Streaming Service details**

# %%
# extract Streaming Service details and append it into list
Tv_show_stream_services = []

for page in Tv_show_data:
  soup_Tv_show = BeautifulSoup(page.text,'html.parser')

  # if the attribute the code is looking for is not present in the website it will append none
  try:
    # if multiple streaming services are available for single movie it will append each into a list
    Tv_show_stream_services.append([ data["alt"] for data in soup_Tv_show.find("div", class_ = "buybox-row stream").find_all("img", class_ = "offer__icon")])

  except AttributeError:
    Tv_show_stream_services.append(None)

# after getting data for each movie it append data into main list
Tv_show_stream_services_join = [None if data == None else ", ".join(data) if len(data) > 1 else data[0] for data in Tv_show_stream_services]

Tv_show_dataset["TV Show Stream Services"] = Tv_show_stream_services_join

# %% [markdown]
# ## **Fetching Duration Details**

# %%
'''
extract runtime of each movie from data pass it onto
'convert_duration_to_timedelta()' function and append the output into a list.
'''
Tv_show_runtime = [str(convert_duration_to_timedelta(key.get('Runtime'))) if key.get('Runtime') else key.get('Runtime') for key in Tv_show_details]
Tv_show_dataset["TV Show Runtime"] = Tv_show_runtime

# %% [markdown]
# ## **Creating TV Show DataFrame**

# %%
# convert dictionary dataset into a dataframe
Tv_show_df = pd.DataFrame(Tv_show_dataset)
Tv_show_df
# Out:
#                                TV Show Title  TV Show Year  \
# 0                                     Shōgun          2024
# 1                                  Panchayat          2020
# 2                                   Mirzapur          2018
# 3                            Game of Thrones          2011
# 4                 Avatar: The Last Airbender          2024
# 5                                  Sunflower          2021
# 6                              Solo Leveling          2024
# 7                                   Maharani          2021
# 8                             True Detective          2014
# 9                              Young Sheldon          2017
# 10                          Maamla Legal Hai          2024
# 11                                   Poacher          2023
# 12                                     Aarya          2020
# 13                                   Mastram          2020
# 14                             The Gentlemen          2024
# 15                                     Farzi          2023
# 16                            Jujutsu Kaisen          2020
# 17                                   One Day          2024
# 18                Avatar: The Last Airbender          2005
# 19                   Death and Other Details          2024
# 20                                      Halo          2022
# 21                          Criminal Justice          2019
# 22                               Yellowstone          2018
# 23                       Indian Police Force          2024
# 24                                   Reacher          2022
# 25                                  Supersex          2024
# 26                                      Loki          2021
# 27                                The Rookie          2018
# 28                                  Euphoria          2019
# 29                                 Scam 1992          2020
# 30                                   Lucifer          2016
# 31  The Indrani Mukerjea Story: Buried Truth          2024
# 32                                    Gullak          2019
# 33                            The Family Man          2019
# 34                               Gandii Baat          2018
# 35                               Money Heist          2017
# 36                                   Aashram          2020
# 37                              Breaking Bad          2008
# 38                                The Twelve          2019
# 39                          Naruto Shippūden          2007
# 40            Demon Slayer: Kimetsu no Yaiba          2019
# 41                 Mashle: Magic and Muscles          2023
# 42                   The Great Indian Murder          2022
# 43                                    Naruto          2002
# 44                        Masters of the Air          2024
# 45                                 Bigg Boss          2006
# 46                                   Apharan          2018
# 47                       House of the Dragon          2022
# 48                                  The Bear          2022
# 49                            The Last of Us          2023
#
#                                        TV Show Genres  TV Show IMDB Rating  \
# 0                      Drama, War & Military, History                  9.2
# 1                                       Comedy, Drama                  8.9
# 2   Crime, Action & Adventure, Drama, Mystery & Th...                  8.5
# 3   Science-Fiction, Drama, Action & Adventure, Fa...                  9.2
# 4   Science-Fiction, Action & Adventure, Drama, Ki...                  7.3
# 5                                       Comedy, Crime                  7.5
# 6   Animation, Action & Adventure, Fantasy, Scienc...                  8.5
# 7                                               Drama                  7.9
# 8                    Drama, Mystery & Thriller, Crime                  8.9
# 9                               Comedy, Kids & Family                  7.6
# 10                                              Drama                  NaN
# 11                                       Crime, Drama                  7.7
# 12  Crime, Drama, Mystery & Thriller, Action & Adv...                  7.9
# 13                             Drama, Fantasy, Comedy                  7.1
# 14           Action & Adventure, Comedy, Crime, Drama                  8.4
# 15                   Crime, Drama, Mystery & Thriller                  8.4
# 16  Mystery & Thriller, Animation, Action & Advent...                  8.6
# 17                             Romance, Comedy, Drama                  8.2
# 18  Action & Adventure, Science-Fiction, Kids & Fa...                  9.3
# 19                   Crime, Mystery & Thriller, Drama                  6.8
# 20  Action & Adventure, Science-Fiction, Mystery &...                  7.3
# 21                   Drama, Crime, Mystery & Thriller                  8.1
# 22                                     Drama, Western                  8.7
# 23                          Crime, Action & Adventure                  5.1
# 24  Mystery & Thriller, Action & Adventure, Crime,...                  8.1
# 25                                     Drama, History                  6.2
# 26  Action & Adventure, Fantasy, Science-Fiction, ...                  8.2
# 27           Drama, Comedy, Action & Adventure, Crime                  8.0
# 28                                              Drama                  8.3
# 29                   Crime, Drama, Mystery & Thriller                  9.3
# 30             Crime, Science-Fiction, Drama, Fantasy                  8.1
# 31                                 Documentary, Crime                  6.3
# 32                       Comedy, Drama, Kids & Family                  9.1
# 33                  Comedy, Drama, Action & Adventure                  8.7
# 34                   Crime, Drama, Mystery & Thriller                  3.4
# 35  Drama, Mystery & Thriller, Action & Adventure,...                  8.2
# 36                   Crime, Drama, Mystery & Thriller                  7.4
# 37                   Drama, Mystery & Thriller, Crime                  9.5
# 38                          Drama, Mystery & Thriller                  7.4
# 39  Action & Adventure, Science-Fiction, Animation...                  8.7
# 40  Mystery & Thriller, Animation, Action & Advent...                  8.7
# 41  Comedy, Fantasy, Animation, Action & Adventure...                  7.6
# 42                          Crime, Mystery & Thriller                  6.8
# 43  Action & Adventure, Science-Fiction, Animation...                  8.4
# 44  War & Military, Drama, Mystery & Thriller, Act...                  7.9
# 45                          Reality TV, Kids & Family                  3.7
# 46  Drama, Action & Adventure, Crime, Mystery & Th...                  8.3
# 47  Science-Fiction, Drama, Action & Adventure, Fa...                  8.4
# 48                                      Drama, Comedy                  8.6
# 49  Drama, Mystery & Thriller, Action & Adventure,...                  8.7
#
#    TV Show Age Rating   TV Show Production Countries  \
# 0                None                  United States
# 1                None                          India
# 2                None                          India
# 3                   U                  United States
# 4                None                  United States
# 5                   A                          India
# 6                None             Japan, South Korea
# 7                  UA                          India
# 8                   U                  United States
# 9                   U                  United States
# 10               None                          India
# 11               None           United States, India
# 12               None                          India
# 13               None                          India
# 14                  A  United States, United Kingdom
# 15               None                          India
# 16               None           Japan, United States
# 17                  A                 United Kingdom
# 18                  U                  United States
# 19               None                  United States
# 20               None                  United States
# 21               None                          India
# 22               None                  United States
# 23                  A                          India
# 24                  A                  United States
# 25               None                          Italy
# 26               None                  United States
# 27               None                  United States
# 28                  A                  United States
# 29               None                          India
# 30                  U                  United States
# 31               None                          India
# 32               None                          India
# 33               None                          India
# 34                  A                          India
# 35               None                          Spain
# 36               None                          India
# 37                  U                  United States
# 38               None                        Belgium
# 39                  U                          Japan
# 40               None                          Japan
# 41               None                          Japan
# 42               None                          India
# 43               None                          Japan
# 44                  A                  United States
# 45               None                          India
# 46               None                          India
# 47                  A                  United States
# 48               None                  United States
# 49                  A                  United States
#
#         TV Show Stream Services TV Show Runtime
# 0                       Hotstar        00:58:00
# 1            Amazon Prime Video        00:33:00
# 2            Amazon Prime Video        00:50:00
# 3                    Jio Cinema        00:59:00
# 4                       Netflix        00:54:00
# 5              VI movies and tv        00:37:00
# 6                   Crunchyroll        00:24:00
# 7    Sony Liv, VI movies and tv        00:44:00
# 8                    Jio Cinema        01:01:00
# 9   Amazon Prime Video, Netflix        00:19:00
# 10                      Netflix        00:38:00
# 11           Amazon Prime Video        00:47:00
# 12                      Hotstar        00:46:00
# 13                         None        00:28:00
# 14                      Netflix        00:50:00
# 15           Amazon Prime Video        00:56:00
# 16         Netflix, Crunchyroll        00:23:00
# 17                      Netflix        00:29:00
# 18                         None        00:24:00
# 19                      Hotstar        00:45:00
# 20                   Jio Cinema        00:52:00
# 21                      Hotstar        00:50:00
# 22                      Netflix        00:50:00
# 23           Amazon Prime Video        00:38:00
# 24           Amazon Prime Video        00:48:00
# 25                      Netflix        00:50:00
# 26                      Hotstar        00:49:00
# 27                         None        00:43:00
# 28                   Jio Cinema        00:58:00
# 29                     Sony Liv        00:52:00
# 30                      Netflix        00:47:00
# 31                      Netflix        00:46:00
# 32                     Sony Liv        00:29:00
# 33           Amazon Prime Video        00:45:00
# 34                   Alt Balaji        00:44:00
# 35                      Netflix        00:50:00
# 36                    MX Player        00:43:00
# 37                      Netflix        00:47:00
# 38  Netflix, Amazon Prime Video        00:54:00
# 39         Netflix, Crunchyroll        00:24:00
# 40         Netflix, Crunchyroll        00:26:00
# 41                  Crunchyroll        00:23:00
# 42                      Hotstar        00:45:00
# 43  Netflix, Amazon Prime Video        00:23:00
# 44                Apple TV Plus        00:56:00
# 45                         None        01:15:00
# 46       Jio Cinema, Alt Balaji        00:24:00
# 47                   Jio Cinema        01:02:00
# 48                      Hotstar        00:34:00
# 49                   Jio Cinema        00:58:00

# %% [markdown]
# ## **Task 2 :- Data Filtering & Analysis**

# %%
# Only include movies released in the last 2 years (from the current date).
movies_last_2years = movie_df[movie_df["Movie Release Year"].isin([2023, 2022])].reset_index(drop=True)
movies_last_2years
# Out:
#                      Movie Title  Movie Release Year  \
# 0                         Animal                2023
# 1                         Salaar                2023
# 2                    Poor Things                2023
# 3                      12th Fail                2023
# 4               The Kerala Story                2023
# 5                          Dunki                2023
# 6                 Anyone But You                2023
# 7                    Sam Bahadur                2023
# 8              Anatomy of a Fall                2023
# 9   Aquaman and the Lost Kingdom                2023
# 10                         Jawan                2023
# 11              American Fiction                2023
# 12              Sound of Freedom                2023
# 13          The Zone of Interest                2023
# 14                        Barbie                2023
# 15                 The Holdovers                2023
# 16    Killers of the Flower Moon                2023
# 17                        Junior                2023
# 18                    Past Lives                2023
# 19                    BlackBerry                2023
# 20            Godzilla Minus One                2023
#
#                                          Movie Genres  Movie IMDB Rating  \
# 0   Action & Adventure, Crime, Drama, Mystery & Th...                6.3
# 1   Action & Adventure, Crime, Drama, Mystery & Th...                6.5
# 2             Science-Fiction, Romance, Comedy, Drama                8.1
# 3                                               Drama                9.0
# 4                                               Drama                7.0
# 5                                       Comedy, Drama                6.7
# 6                                     Comedy, Romance                6.2
# 7                               Drama, War & Military                7.8
# 8                    Mystery & Thriller, Crime, Drama                7.8
# 9        Action & Adventure, Fantasy, Science-Fiction                5.6
# 10      Action & Adventure, Mystery & Thriller, Drama                7.0
# 11                                      Comedy, Drama                7.6
# 12  Action & Adventure, Drama, Crime, History, Mys...                7.7
# 13                     Drama, War & Military, History                7.5
# 14                                    Comedy, Fantasy                6.9
# 15                                      Comedy, Drama                8.0
# 16            Crime, History, Drama, Romance, Western                7.6
# 17                                 Action & Adventure                7.7
# 18                                     Romance, Drama                7.9
# 19                             Comedy, Drama, History                7.4
# 20  Action & Adventure, Science-Fiction, Drama, Ho...                8.3
#
#    Movie Runtime Movie Age Rating              Movie Production Countries  \
# 0       03:21:00                A                                   India
# 1       02:55:00                A                                   India
# 2       02:22:00                A  United Kingdom, United States, Ireland
# 3       02:27:00             None                                   India
# 4       02:18:00                A                                   India
# 5       02:40:00             None                                   India
# 6       01:43:00             None                Australia, United States
# 7       02:30:00               UA                                   India
# 8       02:32:00             None                                  France
# 9       02:04:00             None                           United States
# 10      02:49:00               UA                                   India
# 11      01:57:00             None                           United States
# 12      02:11:00             None                           United States
# 13      01:45:00               UA   United States, Poland, United Kingdom
# 14      01:54:00               UA           United States, United Kingdom
# 15      02:13:00             None                           United States
# 16      03:26:00                A                           United States
# 17      02:02:00             None                                   India
# 18      01:46:00               UA              South Korea, United States
# 19      02:00:00             None                                  Canada
# 20      02:05:00             None                                   Japan
#
#                                 Movie Stream Services
# 0                                             Netflix
# 1                                             Netflix
# 2                                                None
# 3                                             Hotstar
# 4                                                Zee5
# 5                                             Netflix
# 6                                                None
# 7                                                Zee5
# 8                                                None
# 9                                                None
# 10                                            Netflix
# 11                                 Amazon Prime Video
# 12                                 Amazon Prime Video
# 13                                               None
# 14                                         Jio Cinema
# 15                                               None
# 16                                      Apple TV Plus
# 17                                 Amazon Prime Video
# 18  Lionsgate Play, Lionsgate Play Apple TV Channe...
# 19                                 Amazon Prime Video
# 20                                               None

# %% [markdown]
# Note : We have got 20 movies in top 50 movie present on website which were released in the year 2023 & 2022.

# %%
# Only include TV shows released in the last 2 years (from the current date).
Tv_show_last_2years = Tv_show_df[Tv_show_df["TV Show Year"].isin([2023, 2022])].reset_index(drop=True)
Tv_show_last_2years
# Out:
#                TV Show Title  TV Show Year  \
# 0                    Poacher          2023
# 1                      Farzi          2023
# 2                       Halo          2022
# 3                    Reacher          2022
# 4  Mashle: Magic and Muscles          2023
# 5    The Great Indian Murder          2022
# 6        House of the Dragon          2022
# 7                   The Bear          2022
# 8             The Last of Us          2023
#
#                                       TV Show Genres  TV Show IMDB Rating  \
# 0                                       Crime, Drama                  7.7
# 1                   Crime, Drama, Mystery & Thriller                  8.4
# 2  Action & Adventure, Science-Fiction, Mystery &...                  7.3
# 3  Mystery & Thriller, Action & Adventure, Crime,...                  8.1
# 4  Comedy, Fantasy, Animation, Action & Adventure...                  7.6
# 5                          Crime, Mystery & Thriller                  6.8
# 6  Science-Fiction, Drama, Action & Adventure, Fa...                  8.4
# 7                                      Drama, Comedy                  8.6
# 8  Drama, Mystery & Thriller, Action & Adventure,...                  8.7
#
#   TV Show Age Rating TV Show Production Countries TV Show Stream Services  \
# 0               None         United States, India      Amazon Prime Video
# 1               None                        India      Amazon Prime Video
# 2               None                United States              Jio Cinema
# 3                  A                United States      Amazon Prime Video
# 4               None                        Japan             Crunchyroll
# 5               None                        India                 Hotstar
# 6                  A                United States              Jio Cinema
# 7               None                United States                 Hotstar
# 8                  A                United States              Jio Cinema
#
#   TV Show Runtime
# 0        00:47:00
# 1        00:56:00
# 2        00:52:00
# 3        00:48:00
# 4        00:23:00
# 5        00:45:00
# 6        01:02:00
# 7        00:34:00
# 8        00:58:00

# %% [markdown]
# Note : We have got 8 TV Shows in top 50 TV Shows present on website which were released in the year 2023 & 2022.

# %%
# Only include movies with an IMDb rating of 7 or higher.
movies_rating_7 = movie_df[movie_df["Movie IMDB Rating"] >= 7].reset_index(drop=True)
movies_rating_7
# Out:
#                                  Movie Title  Movie Release Year  \
# 0                                Oppenheimer                2024
# 1                                       Dune                2021
# 2                                   Hanu-Man                2024
# 3                                Poor Things                2023
# 4                                  12th Fail                2023
# 5                           The Kerala Story                2023
# 6                                Sam Bahadur                2023
# 7                                Article 370                2024
# 8                            Merry Christmas                2024
# 9           Teri Baaton Mein Aisa Uljha Jiya                2024
# 10                                Bramayugam                2024
# 11                     Anweshippin Kandethum                2024
# 12                         Anatomy of a Fall                2023
# 13                            Manjummel Boys                2024
# 14                            Dune: Part Two                2024
# 15                                     Jawan                2023
# 16                          American Fiction                2023
# 17                           Laapataa Ladies                2024
# 18                          Sound of Freedom                2023
# 19                      The Zone of Interest                2023
# 20                                   Premalu                2024
# 21  Harry Potter and the Philosopher's Stone                2001
# 22                             The Holdovers                2023
# 23                Killers of the Flower Moon                2023
# 24                                    Junior                2023
# 25                                    Aattam                2024
# 26                                Past Lives                2023
# 27                                BlackBerry                2023
# 28                        Godzilla Minus One                2023
#
#                                          Movie Genres  Movie IMDB Rating  \
# 0                                      Drama, History                8.3
# 1          Science-Fiction, Action & Adventure, Drama                8.0
# 2   Action & Adventure, Comedy, Science-Fiction, F...                8.4
# 3             Science-Fiction, Romance, Comedy, Drama                8.1
# 4                                               Drama                9.0
# 5                                               Drama                7.0
# 6                               Drama, War & Military                7.8
# 7       Action & Adventure, Drama, Mystery & Thriller                8.5
# 8                           Drama, Mystery & Thriller                7.2
# 9             Science-Fiction, Comedy, Drama, Romance                7.0
# 10                         Horror, Mystery & Thriller                8.3
# 11                   Crime, Drama, Mystery & Thriller                7.6
# 12                   Mystery & Thriller, Crime, Drama                7.8
# 13                          Mystery & Thriller, Drama                8.7
# 14         Action & Adventure, Science-Fiction, Drama                8.9
# 15      Action & Adventure, Mystery & Thriller, Drama                7.0
# 16                                      Comedy, Drama                7.6
# 17                                      Comedy, Drama                8.4
# 18  Action & Adventure, Drama, Crime, History, Mys...                7.7
# 19                     Drama, War & Military, History                7.5
# 20                                    Comedy, Romance                8.3
# 21         Action & Adventure, Fantasy, Kids & Family                7.6
# 22                                      Comedy, Drama                8.0
# 23            Crime, History, Drama, Romance, Western                7.6
# 24                                 Action & Adventure                7.7
# 25                                              Drama                8.4
# 26                                     Romance, Drama                7.9
# 27                             Comedy, Drama, History                7.4
# 28  Action & Adventure, Science-Fiction, Drama, Ho...                8.3
#
#    Movie Runtime Movie Age Rating              Movie Production Countries  \
# 0       03:01:00               UA           United Kingdom, United States
# 1       02:35:00               UA                           United States
# 2       02:39:00               UA                                   India
# 3       02:22:00                A  United Kingdom, United States, Ireland
# 4       02:27:00             None                                   India
# 5       02:18:00                A                                   India
# 6       02:30:00               UA                                   India
# 7       02:38:00               UA                                   India
# 8       02:23:00             None                                   India
# 9       02:21:00             None                                   India
# 10      02:19:00               UA                                   India
# 11      02:22:00             None                                   India
# 12      02:32:00             None                                  France
# 13      02:15:00               UA                                   India
# 14      02:47:00             None                           United States
# 15      02:49:00               UA                                   India
# 16      01:57:00             None                           United States
# 17      02:02:00             None                                   India
# 18      02:11:00             None                           United States
# 19      01:45:00               UA   United States, Poland, United Kingdom
# 20      02:36:00                U                                   India
# 21      02:32:00                U           United Kingdom, United States
# 22      02:13:00             None                           United States
# 23      03:26:00                A                           United States
# 24      02:02:00             None                                   India
# 25      02:19:00               UA                                   India
# 26      01:46:00               UA              South Korea, United States
# 27      02:00:00             None                                  Canada
# 28      02:05:00             None                                   Japan
#
#                                 Movie Stream Services
# 0                                          Jio Cinema
# 1                                             Netflix
# 2                                                None
# 3                                                None
# 4                                             Hotstar
# 5                                                Zee5
# 6                                                Zee5
# 7                                                None
# 8                                             Netflix
# 9                                                None
# 10                                           Sony Liv
# 11                                            Netflix
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                            Netflix
# 16                                 Amazon Prime Video
# 17                                               None
# 18                                 Amazon Prime Video
# 19                                               None
# 20                                               None
# 21                                         Jio Cinema
# 22                                               None
# 23                                      Apple TV Plus
# 24                                 Amazon Prime Video
# 25                                 Amazon Prime Video
# 26  Lionsgate Play, Lionsgate Play Apple TV Channe...
# 27                                 Amazon Prime Video
# 28                                               None

# %% [markdown]
# Note : We have got 28 movies in top 50 moviess present on website with the IMDB rating of 7 or higher.

# %%
# Only include TV shows with an IMDb rating of 7 or higher.
Tv_show_rating_7 = Tv_show_df[Tv_show_df["TV Show IMDB Rating"] >= 7].reset_index(drop=True)
Tv_show_rating_7
# Out:
#                      TV Show Title  TV Show Year  \
# 0                           Shōgun          2024
# 1                        Panchayat          2020
# 2                         Mirzapur          2018
# 3                  Game of Thrones          2011
# 4       Avatar: The Last Airbender          2024
# 5                        Sunflower          2021
# 6                    Solo Leveling          2024
# 7                         Maharani          2021
# 8                   True Detective          2014
# 9                    Young Sheldon          2017
# 10                         Poacher          2023
# 11                           Aarya          2020
# 12                         Mastram          2020
# 13                   The Gentlemen          2024
# 14                           Farzi          2023
# 15                  Jujutsu Kaisen          2020
# 16                         One Day          2024
# 17      Avatar: The Last Airbender          2005
# 18                            Halo          2022
# 19                Criminal Justice          2019
# 20                     Yellowstone          2018
# 21                         Reacher          2022
# 22                            Loki          2021
# 23                      The Rookie          2018
# 24                        Euphoria          2019
# 25                       Scam 1992          2020
# 26                         Lucifer          2016
# 27                          Gullak          2019
# 28                  The Family Man          2019
# 29                     Money Heist          2017
# 30                         Aashram          2020
# 31                    Breaking Bad          2008
# 32                      The Twelve          2019
# 33                Naruto Shippūden          2007
# 34  Demon Slayer: Kimetsu no Yaiba          2019
# 35       Mashle: Magic and Muscles          2023
# 36                          Naruto          2002
# 37              Masters of the Air          2024
# 38                         Apharan          2018
# 39             House of the Dragon          2022
# 40                        The Bear          2022
# 41                  The Last of Us          2023
#
#                                        TV Show Genres  TV Show IMDB Rating  \
# 0                      Drama, War & Military, History                  9.2
# 1                                       Comedy, Drama                  8.9
# 2   Crime, Action & Adventure, Drama, Mystery & Th...                  8.5
# 3   Science-Fiction, Drama, Action & Adventure, Fa...                  9.2
# 4   Science-Fiction, Action & Adventure, Drama, Ki...                  7.3
# 5                                       Comedy, Crime                  7.5
# 6   Animation, Action & Adventure, Fantasy, Scienc...                  8.5
# 7                                               Drama                  7.9
# 8                    Drama, Mystery & Thriller, Crime                  8.9
# 9                               Comedy, Kids & Family                  7.6
# 10                                       Crime, Drama                  7.7
# 11  Crime, Drama, Mystery & Thriller, Action & Adv...                  7.9
# 12                             Drama, Fantasy, Comedy                  7.1
# 13           Action & Adventure, Comedy, Crime, Drama                  8.4
# 14                   Crime, Drama, Mystery & Thriller                  8.4
# 15  Mystery & Thriller, Animation, Action & Advent...                  8.6
# 16                             Romance, Comedy, Drama                  8.2
# 17  Action & Adventure, Science-Fiction, Kids & Fa...                  9.3
# 18  Action & Adventure, Science-Fiction, Mystery &...                  7.3
# 19                   Drama, Crime, Mystery & Thriller                  8.1
# 20                                     Drama, Western                  8.7
# 21  Mystery & Thriller, Action & Adventure, Crime,...                  8.1
# 22  Action & Adventure, Fantasy, Science-Fiction, ...                  8.2
# 23           Drama, Comedy, Action & Adventure, Crime                  8.0
# 24                                              Drama                  8.3
# 25                   Crime, Drama, Mystery & Thriller                  9.3
# 26             Crime, Science-Fiction, Drama, Fantasy                  8.1
# 27                       Comedy, Drama, Kids & Family                  9.1
# 28                  Comedy, Drama, Action & Adventure                  8.7
# 29  Drama, Mystery & Thriller, Action & Adventure,...                  8.2
# 30                   Crime, Drama, Mystery & Thriller                  7.4
# 31                   Drama, Mystery & Thriller, Crime                  9.5
# 32                          Drama, Mystery & Thriller                  7.4
# 33  Action & Adventure, Science-Fiction, Animation...                  8.7
# 34  Mystery & Thriller, Animation, Action & Advent...                  8.7
# 35  Comedy, Fantasy, Animation, Action & Adventure...                  7.6
# 36  Action & Adventure, Science-Fiction, Animation...                  8.4
# 37  War & Military, Drama, Mystery & Thriller, Act...                  7.9
# 38  Drama, Action & Adventure, Crime, Mystery & Th...                  8.3
# 39  Science-Fiction, Drama, Action & Adventure, Fa...                  8.4
# 40                                      Drama, Comedy                  8.6
# 41  Drama, Mystery & Thriller, Action & Adventure,...                  8.7
#
#    TV Show Age Rating   TV Show Production Countries  \
# 0                None                  United States
# 1                None                          India
# 2                None                          India
# 3                   U                  United States
# 4                None                  United States
# 5                   A                          India
# 6                None             Japan, South Korea
# 7                  UA                          India
# 8                   U                  United States
# 9                   U                  United States
# 10               None           United States, India
# 11               None                          India
# 12               None                          India
# 13                  A  United States, United Kingdom
# 14               None                          India
# 15               None           Japan, United States
# 16                  A                 United Kingdom
# 17                  U                  United States
# 18               None                  United States
# 19               None                          India
# 20               None                  United States
# 21                  A                  United States
# 22               None                  United States
# 23               None                  United States
# 24                  A                  United States
# 25               None                          India
# 26                  U                  United States
# 27               None                          India
# 28               None                          India
# 29               None                          Spain
# 30               None                          India
# 31                  U                  United States
# 32               None                        Belgium
# 33                  U                          Japan
# 34               None                          Japan
# 35               None                          Japan
# 36               None                          Japan
# 37                  A                  United States
# 38               None                          India
# 39                  A                  United States
# 40               None                  United States
# 41                  A                  United States
#
#         TV Show Stream Services TV Show Runtime
# 0                       Hotstar        00:58:00
# 1            Amazon Prime Video        00:33:00
# 2            Amazon Prime Video        00:50:00
# 3                    Jio Cinema        00:59:00
# 4                       Netflix        00:54:00
# 5              VI movies and tv        00:37:00
# 6                   Crunchyroll        00:24:00
# 7    Sony Liv, VI movies and tv        00:44:00
# 8                    Jio Cinema        01:01:00
# 9   Amazon Prime Video, Netflix        00:19:00
# 10           Amazon Prime Video        00:47:00
# 11                      Hotstar        00:46:00
# 12                         None        00:28:00
# 13                      Netflix        00:50:00
# 14           Amazon Prime Video        00:56:00
# 15         Netflix, Crunchyroll        00:23:00
# 16                      Netflix        00:29:00
# 17                         None        00:24:00
# 18                   Jio Cinema        00:52:00
# 19                      Hotstar        00:50:00
# 20                      Netflix        00:50:00
# 21           Amazon Prime Video        00:48:00
# 22                      Hotstar        00:49:00
# 23                         None        00:43:00
# 24                   Jio Cinema        00:58:00
# 25                     Sony Liv        00:52:00
# 26                      Netflix        00:47:00
# 27                     Sony Liv        00:29:00
# 28           Amazon Prime Video        00:45:00
# 29                      Netflix        00:50:00
# 30                    MX Player        00:43:00
# 31                      Netflix        00:47:00
# 32  Netflix, Amazon Prime Video        00:54:00
# 33         Netflix, Crunchyroll        00:24:00
# 34         Netflix, Crunchyroll        00:26:00
# 35                  Crunchyroll        00:23:00
# 36  Netflix, Amazon Prime Video        00:23:00
# 37                Apple TV Plus        00:56:00
# 38       Jio Cinema, Alt Balaji        00:24:00
# 39                   Jio Cinema        01:02:00
# 40                      Hotstar        00:34:00
# 41                   Jio Cinema        00:58:00

# %% [markdown]
# Note : We have got 41 TV Shows in top 50 TV Shows present on website with the rating of 7 or higher.

# %% [markdown]
# ## **Calculating Mean IMDB Ratings for both Movies and Tv Shows**

# %%
Movie_mean_imdb = movie_df["Movie IMDB Rating"].mean()
print("Mean IMDB rating for movies:", round(Movie_mean_imdb, 3))

Tv_show_mean_imdb = Tv_show_df["TV Show IMDB Rating"].mean()
print("Mean IMDB rating for TV shows:", round(Tv_show_mean_imdb, 3))
# Out:
# Mean IMDB rating for movies: 7.18
# Mean IMDB rating for TV shows: 7.9

# %% [markdown]
# ## **Analyzing Top Genres**

# %%
# Group by "Genre" and count occurrences for movies

# split genres of each movie into individual genre and append to a list
all_movie_genres = [genre.strip() for element in movie_df["Movie Genres"] for genre in element.split(",")]
all_movie_genres_dict = {"Genres": all_movie_genres}

# convert to dataframe
all_movie_genres_count_df = pd.DataFrame(all_movie_genres_dict)

# Group by Genre and count the occurrences
genre_counts = all_movie_genres_count_df.groupby('Genres').size().reset_index(name='Count')

# Sort the DataFrame by Count column in descending order
genre_counts_sorted = genre_counts[["Genres", "Count"]].sort_values(by='Count', ascending=False)

genre_counts_sorted.head()
# Out:
#                 Genres  Count
# 3                Drama     36
# 0   Action & Adventure     23
# 9   Mystery & Thriller     18
# 1               Comedy     14
# 11     Science-Fiction     11

# %%
#Let's Visualize it using word cloud
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Convert genre_counts_sorted DataFrame to a dictionary
genre_counts_dict = dict(zip(genre_counts_sorted['Genres'], genre_counts_sorted['Count']))

# Generate the word cloud
wordcloud = WordCloud(width=800, height=400, background_color ='white').generate_from_frequencies(genre_counts_dict)

# Plot the word cloud
plt.figure(figsize=(10, 8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# Note : The above image explains about the popularity of genres among the top 50 movies on the website. Bolder the genre more popular it is among the folks.

# %%
# Group by "Genre" and count occurrences for Tv Shows

# split genres of each movie into individual genre and append to a list
all_Tv_show_genres = [genre.strip() for element in Tv_show_df["TV Show Genres"] for genre in element.split(",")]
all_Tv_show_genres_dict = {"Genres": all_Tv_show_genres}

# convert to dataframe
all_Tv_show_genres_count_df = pd.DataFrame(all_Tv_show_genres_dict)

# Group by Genre and count the occurrences
Tv_show_genre_counts = all_Tv_show_genres_count_df.groupby('Genres').size().reset_index(name='Count')

# Sort the DataFrame by Count column in descending order
Tv_show_genre_counts_sorted = Tv_show_genre_counts[["Genres", "Count"]].sort_values(by='Count', ascending=False)

Tv_show_genre_counts_sorted.head()
# Out:
#                 Genres  Count
# 5                Drama     37
# 0   Action & Adventure     23
# 3                Crime     21
# 11  Mystery & Thriller     20
# 2               Comedy     14

# %%
#Let's Visualize it using word cloud
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Convert genre_counts_sorted DataFrame to a dictionary
Tv_show_genre_counts_dict = dict(zip(Tv_show_genre_counts_sorted['Genres'], Tv_show_genre_counts_sorted['Count']))

# Generate the word cloud
wordcloud = WordCloud(width=800, height=400, background_color ='white').generate_from_frequencies(Tv_show_genre_counts_dict)

# Plot the word cloud
plt.figure(figsize=(10, 8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# Note : The above image explains about the popularity of genres among the top 50 TV Shows on the website. Bolder the genre more popular it is among the folks.

# %% [markdown]
# ## **Finding Predominant Streaming Service**

# %%
# Group by "Streaming Platform" and count occurrences for movies

# split genres of each movie into individual genre and append to a list
all_movie_Stream = [Stream.strip() for element in movie_df["Movie Stream Services"] if element != None for Stream in element.split(",")]
all_movie_Stream_dict = {"Movie Stream Services": all_movie_Stream}

# convert to dataframe
all_movie_Stream_count_df = pd.DataFrame(all_movie_Stream_dict)

# Group by Genre and count the occurrences
Stream_counts = all_movie_Stream_count_df.groupby('Movie Stream Services').size().reset_index(name='Count')

# Sort the DataFrame by Count column in descending order
Stream_counts_sorted = Stream_counts[["Movie Stream Services", "Count"]].sort_values(by='Count', ascending=False)

Stream_counts_sorted.head()
# Out:
#    Movie Stream Services  Count
# 0     Amazon Prime Video     11
# 7                Netflix     11
# 3             Jio Cinema      3
# 9                Sun Nxt      2
# 10                  Zee5      2

# %%
#Let's Visualize it using word cloud
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Convert genre_counts_sorted DataFrame to a dictionary
Stream_counts_dict = dict(zip(Stream_counts_sorted['Movie Stream Services'], Stream_counts_sorted['Count']))

# Generate the word cloud
wordcloud = WordCloud(width=800, height=400, background_color ='white').generate_from_frequencies(Stream_counts_dict)

# Plot the word cloud
plt.figure(figsize=(10, 8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# Note : The above image explains about the popularity of streaming Services among the top 50 Movies on the website. Bolder the genre more popular it is among the folks.

# %%
# Group by "Genre" and count occurrences for Tv Shows

# split genres of each movie into individual genre and append to a list
all_Tv_show_Stream = [Stream.strip() for element in Tv_show_df["TV Show Stream Services"] if element != None for Stream in element.split(",")]
all_Tv_show_Stream_dict = {"TV Show Stream Services": all_Tv_show_Stream}

# convert to dataframe
all_Tv_show_Stream_count_df = pd.DataFrame(all_Tv_show_Stream_dict)

# Group by Genre and count the occurrences
Tv_show_Stream_counts = all_Tv_show_Stream_count_df.groupby('TV Show Stream Services').size().reset_index(name='Count')

# Sort the DataFrame by Count column in descending order
Tv_show_Stream_counts_sorted = Tv_show_Stream_counts[["TV Show Stream Services", "Count"]].sort_values(by='Count', ascending=False)

Tv_show_Stream_counts_sorted.head()
# Out:
#   TV Show Stream Services  Count
# 7                 Netflix     16
# 1      Amazon Prime Video     10
# 4                 Hotstar      7
# 5              Jio Cinema      7
# 3             Crunchyroll      5

# %%
#Let's Visualise it using word cloud
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Convert genre_counts_sorted DataFrame to a dictionary
Tv_show_Stream_counts_dict = dict(zip(Tv_show_Stream_counts_sorted['TV Show Stream Services'], Tv_show_Stream_counts_sorted['Count']))

# Generate the word cloud
wordcloud = WordCloud(width=800, height=400, background_color ='white').generate_from_frequencies(Tv_show_Stream_counts_dict)

# Plot the word cloud
plt.figure(figsize=(10, 8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# Note : The above image explains about the popularity of streaming Services among the top 50 TV Shows on the website. Bolder the genre more popular it is among the folks.

# %% [markdown]
# ## **Task 3 :- Data Export**

# %%
# Mounting the drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#saving final dataframe as Final Data in csv format
movie_df.to_csv("/content/drive/My Drive/Almabetter/Module 2/Top_50_Movies_DF.csv")

Tv_show_df.to_csv("/content/drive/My Drive/Almabetter/Module 2/Top_50_Tv_shows_DF.csv")

# %%
#saving filter data as Filter Data in csv format
movies_last_2years.to_csv("/content/drive/My Drive/Almabetter/Module 2/Top_Movies_released_last_2years_DF.csv")

Tv_show_last_2years.to_csv("/content/drive/My Drive/Almabetter/Module 2/Top_TV_shows_released_last_2years_DF.csv")

movies_rating_7.to_csv("/content/drive/My Drive/Almabetter/Module 2/Movies_IMDB_rating_above7_DF.csv")

Tv_show_rating_7.to_csv("/content/drive/My Drive/Almabetter/Module 2/TV_shows_IMDB_rating_above7_DF.csv")

# %% [markdown]
# # **You can further upgrade the code as per your requirement**

# %% [markdown]
# # ***End of the Project.***
